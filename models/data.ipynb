# %%
import pandas as pd
import json

# %%
import cv2
import mediapipe as mp
import pandas as pd
import os

mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5)

landmark_names = [
    'nose', 'left_eye_inner', 'left_eye', 'left_eye_outer', 'right_eye_inner', 'right_eye', 'right_eye_outer',
    'left_ear', 'right_ear', 'mouth_left', 'mouth_right', 'left_shoulder', 'right_shoulder', 'left_elbow',
    'right_elbow', 'left_wrist', 'right_wrist', 'left_pinky', 'right_pinky', 'left_index', 'right_index',
    'left_thumb', 'right_thumb', 'left_hip', 'right_hip', 'left_knee', 'right_knee', 'left_ankle', 'right_ankle',
    'left_heel', 'right_heel', 'left_foot_index', 'right_foot_index'
]

data = []

for i in range(1, 50):
    path = f"../data/good/goodposture{i}.jpg"
    image = cv2.imread(path)
    rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = pose.process(rgb_image)
    landmarks = []
    for name in landmark_names:
        idx = mp_pose.PoseLandmark[name.upper()].value
        lm = results.pose_landmarks.landmark[idx]
        landmarks.append([lm.x, lm.y, lm.z, lm.visibility])
    data.append([landmarks, 1])

for i in range(1, 50):
    path = f"../data/bad/slouched{i}.jpg"
    image = cv2.imread(path)
    rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = pose.process(rgb_image)
    landmarks = []
    for name in landmark_names:
        idx = mp_pose.PoseLandmark[name.upper()].value
        lm = results.pose_landmarks.landmark[idx]
        landmarks.append([lm.x, lm.y, lm.z, lm.visibility])
    data.append([landmarks, 0])

with open('data.json', 'w') as f:
    json.dump(data, f)

# %%
data = pd.read_csv("data.csv")

mp_pose = mp.solutions.pose
pose = mp_pose.Pose(min_detection_confidence=0.7, min_tracking_confidence=0.5)
mp_drawing = mp.solutions.drawing_utils

for i in range(1, 22):
  getLabel(f"../data/good/goodposture{i}.jpg")


for i in range(1, 20):
  getLabel(f"../data/bad/slouched{i}.jpg")


landmarks_data = []
for index, row in data.iterrows():
    #upper body parts
    nose = [row['nose_x'], row['nose_y'], row['nose_z']]
    left_eye_inner = [row['left_eye_inner_x'], row['left_eye_inner_y'], row['left_eye_inner_z']]
    left_eye = [row['left_eye_x'], row['left_eye_y'], row['left_eye_z']]
    left_eye_outer = [row['left_eye_outer_x'], row['left_eye_outer_y'], row['left_eye_outer_z']]
    right_eye_inner = [row['right_eye_inner_x'], row['right_eye_inner_y'], row['right_eye_inner_z']]
    right_eye = [row['right_eye_x'], row['right_eye_y'], row['right_eye_z']]
    right_eye_outer = [row['right_eye_outer_x'], row['right_eye_outer_y'], row['right_eye_outer_z']]
    left_ear = [row['left_ear_x'], row['left_ear_y'], row['left_ear_z']]
    right_ear = [row['right_ear_x'], row['right_ear_y'], row['right_ear_z']]
    mouth_left = [row['mouth_left_x'], row['mouth_left_y'], row['mouth_left_z']]
    mouth_right = [row['mouth_right_x'], row['mouth_right_y'], row['mouth_right_z']]
    left_shoulder = [row['left_shoulder_x'], row['left_shoulder_y'], row['left_shoulder_z']]
    right_shoulder = [row['right_shoulder_x'], row['right_shoulder_y'], row['right_shoulder_z']]
    left_elbow = [row['left_elbow_x'], row['left_elbow_y'], row['left_elbow_z']]
    right_elbow = [row['right_elbow_x'], row['right_elbow_y'], row['right_elbow_z']]
    left_wrist = [row['left_wrist_x'], row['left_wrist_y'], row['left_wrist_z']]
    right_wrist = [row['right_wrist_x'], row['right_wrist_y'], row['right_wrist_z']]
    left_pinky = [row['left_pinky_x'], row['left_pinky_y'], row['left_pinky_z']]
    right_pinky = [row['right_pinky_x'], row['right_pinky_y'], row['right_pinky_z']]
    left_index = [row['left_index_x'], row['left_index_y'], row['left_index_z']]
    right_index = [row['right_index_x'], row['right_index_y'], row['right_index_z']]
    left_thumb = [row['left_thumb_x'], row['left_thumb_y'], row['left_thumb_z']]
    right_thumb = [row['right_thumb_x'], row['right_thumb_y'], row['right_thumb_z']]
    #lower body parts
    left_hip = [row['left_hip_x'], row['left_hip_y'], row['left_hip_z']]
    right_hip = [row['right_hip_x'], row['right_hip_y'], row['right_hip_z']]
    left_knee = [row['left_knee_x'], row['left_knee_y'], row['left_knee_z']]
    right_knee = [row['right_knee_x'], row['right_knee_y'], row['right_knee_z']]
    left_ankle = [row['left_ankle_x'], row['left_ankle_y'], row['left_ankle_z']]
    right_ankle = [row['right_ankle_x'], row['right_ankle_y'], row['right_ankle_z']]
    left_heel = [row['left_heel_x'], row['left_heel_y'], row['left_heel_z']]
    right_heel = [row['right_heel_x'], row['right_heel_y'], row['right_heel_z']]
    left_foot = [row['left_foot_index_x'], row['left_foot_index_y'], row['left_foot_index_z']]
    right_foot = [row['right_foot_index_x'], row['right_foot_index_y'], row['right_foot_index_z']]
    upper_landmarks = [nose, left_eye_inner, left_eye, left_eye_outer, right_eye_inner, right_eye, right_eye_outer, left_ear, right_ear, mouth_left, mouth_right, left_shoulder, right_shoulder, left_elbow, right_elbow, left_wrist, right_wrist, left_pinky, right_pinky, left_index, right_index, left_thumb, right_thumb]
    map = {
    'TUP': 1,
    'TLB': 2,
    'TLF': 3,
    'TLR': 4,
    'TLL': 5,
    }

    label_value = map.get(row['upperbody_label'])
    landmarks_data.append([upper_landmarks, label_value])
with open('data.json', 'w') as f:
    json.dump(landmarks_data, f)

# %%
[1, 1, 1] # <- nose
[[1, 1, 1], [2, 2, 2], ...] # <- nose, left eye inner, left heel, etc
[[[1, 1, 1], [2, 2, 2], ...], [[1, 1, 1], [2, 2, 2], ...], [[1, 1, 1], [2, 2, 2], ...]] # <- each individual array is passed to the model
# Out:
# [[[1, 1, 1], [2, 2, 2], Ellipsis],
#  [[1, 1, 1], [2, 2, 2], Ellipsis],
#  [[1, 1, 1], [2, 2, 2], Ellipsis]]

# %%
import cv2
import numpy as np
import mediapipe as mp
from mediapipe.framework.formats import landmark_pb2

mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

blank_frame = np.zeros((256, 256, 3), dtype=np.uint8)

# List of landmark names in the order MediaPipe expects
landmark_names = [
    'nose', 'left_eye_inner', 'left_eye', 'left_eye_outer', 'right_eye_inner', 'right_eye', 'right_eye_outer',
    'left_ear', 'right_ear', 'mouth_left', 'mouth_right', 'left_shoulder', 'right_shoulder', 'left_elbow',
    'right_elbow', 'left_wrist', 'right_wrist', 'left_pinky', 'right_pinky', 'left_index', 'right_index',
    'left_thumb', 'right_thumb', 'left_hip', 'right_hip', 'left_knee', 'right_knee', 'left_ankle', 'right_ankle',
    'left_heel', 'right_heel', 'left_foot_index', 'right_foot_index'
]

landmarks = []
row = data.iloc[0]
for name in landmark_names:
    x = row[f'{name}_x']
    y = row[f'{name}_y']
    z = row.get(f'{name}_z', 0.0)  # Use 0.0 if z is missing
    landmarks.append(landmark_pb2.NormalizedLandmark(x=x, y=y, z=z))

landmark_list = landmark_pb2.NormalizedLandmarkList(landmark=landmarks)

mp_drawing.draw_landmarks(blank_frame, landmark_list, mp_pose.POSE_CONNECTIONS)
cv2.imshow("Woah", blank_frame)
cv2.waitKey(0)  # Waits indefinitely for a key press
cv2.destroyAllWindows()  # Closes the window after a key is pressed

# %%
import cv2
import numpy as np
import mediapipe as mp

# Initialize MediaPipe Hands
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(min_detection_confidence=0.7,
                       min_tracking_confidence=0.5)
mp_drawing = mp.solutions.drawing_utils

# Open webcam
cap = cv2.VideoCapture(0)

landmarks = []
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Flip the frame horizontally for a mirrored view
    frame = cv2.flip(frame, 1)

    # Convert the BGR image to RGB
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Process the frame with MediaPipe Hands
    results = pose.process(rgb_frame)

    # print(type(results.pose_landmarks))
    landmarks.append(results.pose_landmarks)

    # Draw hand landmarks if detected
    if results.pose_landmarks:
        mp_drawing.draw_landmarks(
            frame, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

    # Display the frame
    cv2.imshow('MediaPipe Hand Tracking', frame)

    # Exit if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
pose.close()
cap.release()
cv2.destroyAllWindows()

# %%
data = []

for i, landmark in enumerate(landmarks[0].landmark):
  data.append([landmark.x, landmark.y, landmark.visibility])
  print(landmark)
# Out:
# x: 0.696406364
# y: 0.301912576
# z: -1.22071028
# visibility: 0.999789417
#
# x: 0.711333156
# y: 0.238704681
# z: -1.14707303
# visibility: 0.999579608
#
# x: 0.724056602
# y: 0.239943981
# z: -1.14733899
# visibility: 0.999554098
#
# x: 0.736935854
# y: 0.241262913
# z: -1.14732873
# visibility: 0.99942553
#
# x: 0.663240969
# y: 0.235795736
# z: -1.17617965
# visibility: 0.999725282
#
# x: 0.639987
# y: 0.235771045
# z: -1.17605674
# visibility: 0.999782383
#
# x: 0.615409
# y: 0.237026826
# z: -1.17661619
# visibility: 0.999787748
#
# x: 0.735137403
# y: 0.269437909
# z: -0.666463673
# visibility: 0.999457657
#
# x: 0.559208632
# y: 0.271661639
# z: -0.79201591
# visibility: 0.999883175
#
# x: 0.713557363
# y: 0.371393085
# z: -1.03803921
# visibility: 0.999814212
#
# x: 0.655462563
# y: 0.369271964
# z: -1.07383895
# visibility: 0.999927759
#
# x: 0.844586253
# y: 0.62008816
# z: -0.308202654
# visibility: 0.996193647
#
# x: 0.400108039
# y: 0.62043488
# z: -0.54830265
# ...

# %%
data[0]
# Out:
# [0.696406364440918, 0.3019125759601593, 0.9997894167900085]
